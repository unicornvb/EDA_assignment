# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/Vaibhavi/Downloads/HR analytics dataset.zip")

# %%
data.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 0                  1                      1           0                  77
# ...

# %%
data.shape #shows size od the data
# Out:
# (17415, 13)

# %%
data.isnull().sum() #shows columns with null entry
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
data.drop_duplicates(inplace=True) #removes duplicates from data

# %%
data.shape #printing size of data after removing duplicates
# Out:
# (17415, 13)

# %%
#From this we know that two rows are deleted which were duplicates

# %%
data.nunique()
# Out:
# employee_id              17414
# department                   9
# region                      34
# education                    3
# gender                       2
# recruitment_channel          3
# no_of_trainings              9
# age                         41
# previous_year_rating         5
# length_of_service           34
# KPIs_met_more_than_80        2
# awards_won                   2
# avg_training_score          61
# dtype: int64

# %%
data.info()#for printing basic information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17415 entries, 0 to 17416
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            17415 non-null  int64
#  1   department             17415 non-null  object
#  2   region                 17415 non-null  object
#  3   education              16644 non-null  object
#  4   gender                 17415 non-null  object
#  5   recruitment_channel    17415 non-null  object
#  6   no_of_trainings        17415 non-null  int64
#  7   age                    17415 non-null  int64
#  8   previous_year_rating   16052 non-null  float64
#  9   length_of_service      17415 non-null  int64
#  10  KPIs_met_more_than_80  17415 non-null  int64
#  11  awards_won             17415 non-null  int64
#  12  avg_training_score     17415 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.9+ MB

# %%
data.describe()#for printing statistics of numeric columns
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  17415.000000     17415.000000  17415.000000          16052.000000
# mean   39082.285214         1.250761     34.807982              3.345751
# std    22708.049139         0.595720      7.694464              1.265194
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19280.500000         1.000000     29.000000              3.000000
# 50%    39115.000000         1.000000     33.000000              3.000000
# 75%    58838.500000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met_more_than_80    awards_won  \
# count       17415.000000           17415.000000  17415.000000
# mean            5.801493               0.358886      0.023371
# std             4.175632               0.479687      0.151082
# ...

# %% [markdown]
# UNIVARIATE Analysis

# %%
data.columns #shows names of columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met_more_than_80', 'awards_won',
#        'avg_training_score'],
#       dtype='object')

# %%
num_cols=[col for col in data.columns if data[col].dtypes=="int64" or data[col].dtypes=="float64"]
num_cols
#shows the columns which are numerical
# Out:
# ['employee_id',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met_more_than_80',
#  'awards_won',
#  'avg_training_score']

# %%
#Numerical column Analysis

# %% [markdown]
# 1] no_of_trainings

# %%
data["no_of_trainings"].value_counts()
# Out:
# no_of_trainings
# 1    14059
# 2     2628
# 3      539
# 4      137
# 5       26
# 6       16
# 7        6
# 8        2
# 9        2
# Name: count, dtype: int64

# %%
sns.histplot(data=data,x="no_of_trainings",color="orange")
# Out:
# <Axes: xlabel='no_of_trainings', ylabel='Count'>

# %% [markdown]
# 2]Age

# %%
sns.histplot(data=data,x="age",bins=22,color="olive",kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#we can see maximum eploys are young peak of the graph is near 34

# %% [markdown]
# 3]length_of_service

# %%
sns.histplot(data=data,x="length_of_service",bins=15,color="purple",kde=True)
# Out:
# <Axes: xlabel='length_of_service', ylabel='Count'>

# %%
# no. people served for 1-4 years are maximum

# %% [markdown]
# 4]KPIs_met_more_than_80

# %%
data.KPIs_met_more_than_80.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.countplot(data=data,x="KPIs_met_more_than_80" , palette=["pink","green"])
# Out:
# C:\Users\Vaibhavi\AppData\Local\Temp\ipykernel_13152\2489263576.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data,x="KPIs_met_more_than_80" , palette=["pink","green"])
# <Axes: xlabel='KPIs_met_more_than_80', ylabel='count'>

# %%
counts=data["KPIs_met_more_than_80"].value_counts()
plt.figure(figsize=(8,8))
plt.pie(counts,labels=counts.index,autopct='%1.1f%%',colors=["pink","green"])
plt.title('Distribution of KPIs Met More Than 80%')
plt.show()

# %%
#64% of employees havent achieved Key Performance Indicators,need to imoprove it.

# %% [markdown]
# 5]Awards Won

# %%
counts=data["awards_won"].value_counts()
plt.figure(figsize=(8,8))
plt.pie(counts,labels=counts.index,autopct='%1.2f%%',colors=["pink","green"])
plt.title('Awards Won')
plt.show()

# %%
#2.34% employees of the company won the award which were cream employees of the company

# %% [markdown]
# 6] ang_training_score

# %%
sns.histplot(data=data,x="avg_training_score",bins=25,kde=True,color="cyan")
# Out:
# <Axes: xlabel='avg_training_score', ylabel='Count'>

# %%
sns.countplot(data=data,x="previous_year_rating",color="orange")
# Out:
# <Axes: xlabel='previous_year_rating', ylabel='count'>

# %%
##Categorical Column Analysis

# %%
cat_cols=[col for col in data.columns if data[col].dtypes=="object"]
cat_cols
# Out:
# ['department', 'region', 'education', 'gender', 'recruitment_channel']

# %% [markdown]
# 1]Department

# %%
data.department.value_counts()
# Out:
# department
# Sales & Marketing    5458
# Operations           3524
# Procurement          2240
# Technology           2199
# Analytics            1697
# HR                    831
# Finance               802
# Legal                 332
# R&D                   332
# Name: count, dtype: int64

# %%
sns.countplot(data=data,y="department",color="plum")
# Out:
# <Axes: xlabel='count', ylabel='department'>

# %%
counts=data["department"].value_counts()
plt.figure(figsize=(8,8))
plt.pie(counts,labels=counts.index,autopct='%1.1f%%',colors=["plum","green","cyan"])
plt.title('department')
plt.show()

# %%
#operations and sacles marketing are the main department of the company

# %% [markdown]
# 2]Education

# %%
sns.countplot(data=data,x="education",color="pink")
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
#maximum employees did education till bachelors

# %% [markdown]
# 3]Gender

# %%
counts=data["gender"].value_counts()
plt.figure(figsize=(8,8))
plt.pie(counts,labels=counts.index,autopct='%1.1f%%',colors=["pink","plum"])
plt.title('gender')
plt.show()

# %%
#most of the employees are male

# %% [markdown]
# 4]recritment_channel

# %%
counts=data["recruitment_channel"].value_counts()
plt.figure(figsize=(8,8))
plt.pie(counts,labels=counts.index,autopct='%1.1f%%',colors=["plum","gold","cyan"])
plt.title('recruitment_channel')
plt.show()

# %% [markdown]
# 5]Region

# %%
sns.countplot(data=data,y="region",color="green")
# Out:
# <Axes: xlabel='count', ylabel='region'>

# %%
#maximum employee belong to Region 2

# %%
#analysis of individual columns is done

# %% [markdown]
# filling nan values based on previos year rating using meadian(mode)

# %%
from sklearn.impute import SimpleImputer
si1=SimpleImputer(strategy="median")
imputed_values=si1.fit_transform(data[["previous_year_rating"]])
data["previous_year_rating"]=imputed_values

# %%
#fillna
mode=data['education'].mode()[0]
data['education']=data['education'].fillna(mode)

# %%
data.isnull().sum()
# Out:
# employee_id              0
# department               0
# region                   0
# education                0
# gender                   0
# recruitment_channel      0
# no_of_trainings          0
# age                      0
# previous_year_rating     0
# length_of_service        0
# KPIs_met_more_than_80    0
# awards_won               0
# avg_training_score       0
# dtype: int64

# %% [markdown]
# BIVARIATE Analysis

# %% [markdown]
# 1]Numerical and Numerical

# %%
numerical_data=data.select_dtypes(include=['float64','int64'])
correlation_matrix=numerical_data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,fmt=".2f",cmap='YlGnBu',square=True,cbar=True,linewidth=0.5)
plt.title('Heatmap of correlation Matrix for Numerical Data')
plt.show()

# %% [markdown]
# 2]Categorical and Categorical

# %%
from itertools import combinations

# %%
cat_col=cat_cols.remove('region')
for col1,col2 in combinations(cat_cols,2):
    plt.figure(figsize=(10,6))
    sns.countplot(data=data,y=col1,hue=col2,palette='Set1')
    plt.title(f'count of{col1} by {col2}')
    plt.xlabel(col1)
    plt.ylabel('count')
    plt.legend(title=col2)
    plt.show()

# %% [markdown]
# Above are the count plots for various combinations of categorical columns

# %%
from scipy.stats import chi2_contingency
from itertools import combinations
for col1,col2 in combinations(cat_cols,2):
    contingency_table=pd.crosstab(data[col1],data[col2])
    chi2,p,dof,expected=chi2_contingency(contingency_table)
    print(f"chi-square Test between {col1} and {col2}:")
    print(f"chi2 Statistic:{chi2:.4f},p-value:{p:.4f},Degree of Freedom:{dof}")
# Out:
# chi-square Test between department and education:
# chi2 Statistic:666.9727,p-value:0.0000,Degree of Freedom:16
# chi-square Test between department and gender:
# chi2 Statistic:1455.5721,p-value:0.0000,Degree of Freedom:8
# chi-square Test between department and recruitment_channel:
# chi2 Statistic:186.5725,p-value:0.0000,Degree of Freedom:16
# chi-square Test between education and gender:
# chi2 Statistic:24.3116,p-value:0.0000,Degree of Freedom:2
# chi-square Test between education and recruitment_channel:
# chi2 Statistic:15.8727,p-value:0.0032,Degree of Freedom:4
# chi-square Test between gender and recruitment_channel:
# chi2 Statistic:0.8854,p-value:0.6423,Degree of Freedom:2

# %%
#both categorical data are independent if p value is larger

# %% [markdown]
# 3]Numerical and Categorical

# %%
from itertools import product
for num_col, cat_col in product(num_cols, cat_cols):
    summary=data.groupby(cat_col).agg(
        mean_value=(num_col, 'mean'),
        std_value=(num_col, 'std'),
        count=(num_col, 'size')
    ).reset_index()

    summary['std_error']=summary['std_value'] / summary['count']**0.5
    plt.figure(figsize=(12,6))
    sns.lineplot(data=summary, x=cat_col, y='mean_value', marker='o')
    plt.errorbar(x=summary[cat_col],
                 y=summary['mean_value'],
                 yerr=summary['std_error'],
                 fmt='none',
                 c='black',
                capsize=5)
    plt.title(f'mean{num_col} by {cat_col}')
    plt.xlabel(cat_col)
    plt.ylabel(f'mean{num_col}')
    plt.grid()
    plt.show()

# %%
#constants
from scipy import stats
SAMPLE_SIZE_THRESHOLD=30
SIGNIFICANCE_LEVEL=0.05
for cat_col, num_col in product(cat_cols, num_cols):
    filtered_data=data[[cat_col, num_col]].dropna()
    groups=filtered_data.groupby(cat_col)[num_col]
    unique_categories=filtered_data[cat_col].unique()
    if len(unique_categories)<2:
        print(f"skipping{cat_col}-{num_col}:less then two categories")
        continue
    #handle binary categorical columns (T-test)
    if len(unique_categories)==2:
        group1=groups.get_group(unique_categories[0])
        group2=groups.get_group(unique_categories[1])
        #checking appropriate test based on sample size
        if len(group1)>SAMPLE_SIZE_THRESHOLD and len(group2)>SAMPLE_SIZE_THRESHOLD:
            #perform z-test approximation using T-test
            stat,p_value=stats.ttest_ind(group1,group2,equal_var=False)
            test_type="z-test (T-test approximation)"
        else:
            #perform T-test
            stat, p_value=stats.ttest_ind(group1,group2,equal_var=False)
            test_type="T-test"
        #print results
        print(f"{test_type} between {cat_col} and {num_col}:")
        print(f"Statistic:{stat:.4f},p-value:{p_value:.4f}")

        if p_value<SIGNIFICANCE_LEVEL:
            print(f"Reject the null hypothesis (p-value<{SIGNIFICANCE_LEVEL})")
        else:
            print(f"Fail to reject the null hypothesis (p-value>={SIGNIFICANCE_LEVEL})")

    else:
        category_data=[group for _,group in groups]
        #perform ANOVA
        stat, p_value=stats.f_oneway(*category_data)
        test_type="ANOVA"
        print(f"{test_type} between {cat_col} and {num_col}:")
        if p_value<SIGNIFICANCE_LEVEL:
            print(f"Reject the null hypothesis (p_value<{SIGNIFICANCE_LEVEL})")
        else:
            print(f"Fail to reject the null hypothesis (p_value>={SIGNIFICANCE_LEVEL})")
    print("\n")
# Out:
# ANOVA between department and employee_id:
# Fail to reject the null hypothesis (p_value>=0.05)
#
#
# ANOVA between department and no_of_trainings:
# Reject the null hypothesis (p_value<0.05)
#
#
# ANOVA between department and age:
# Reject the null hypothesis (p_value<0.05)
#
#
# ANOVA between department and previous_year_rating:
# Reject the null hypothesis (p_value<0.05)
#
#
# ANOVA between department and length_of_service:
# Reject the null hypothesis (p_value<0.05)
#
#
# ANOVA between department and KPIs_met_more_than_80:
# Reject the null hypothesis (p_value<0.05)
#
#
# ANOVA between department and awards_won:
# Fail to reject the null hypothesis (p_value>=0.05)
#
#
# ANOVA between department and avg_training_score:
# Reject the null hypothesis (p_value<0.05)
#
#
# ANOVA between education and employee_id:
# Fail to reject the null hypothesis (p_value>=0.05)
#
#
# ANOVA between education and no_of_trainings:
# Reject the null hypothesis (p_value<0.05)
#
#
# ...

# %%
# lets check for outliers
sns.boxplot(data=data,x="length_of_service")
# Out:
# <Axes: xlabel='length_of_service'>

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data['length_of_service'].quantile(0.25)
Q3 = data['length_of_service'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to remove outliers
data_filtered = data[(data['length_of_service'] >= lower_bound) & (data['length_of_service'] <= upper_bound)]

# Optionally, print the number of rows before and after
print(f'Original data size: {data.shape[0]}')
print(f'Filtered data size: {data_filtered.shape[0]}')
# Out:
# Original data size: 17415
# Filtered data size: 16332

# %%
# Before the size of the column was 17415 , after removing outliers it became 16332

# %%
sns.boxplot(data=data,x="age")
# Out:
# <Axes: xlabel='age'>

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data['age'].quantile(0.25)
Q3 = data['age'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to remove outliers
data_filtered = data[(data['age'] >= lower_bound) & (data['age'] <= upper_bound)]

# Optionally, print the number of rows before and after
print(f'Original data size: {data.shape[0]}')
print(f'Filtered data size: {data_filtered.shape[0]}')
# Out:
# Original data size: 17415
# Filtered data size: 16962

# %%
# Before the size of the column was 17415 , after removing outliers it became 16962

# %% [markdown]
# Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le_department = LabelEncoder()
le_region = LabelEncoder()

# Apply Label Encoding to the 'department' column
data['department_encoded'] = le_department.fit_transform(data['department'])

# Apply Label Encoding to the 'region' column
data['region_encoded'] = le_region.fit_transform(data['region'])
# Drop the original categorical columns
data = data.drop(columns=['department', 'region'])
# Display the resulting DataFrame
print(data)
# Out:
#        employee_id  education gender recruitment_channel  no_of_trainings  \
# 0             8724  Bachelors      m            sourcing                1
# 1            74430  Bachelors      f               other                1
# 2            72255  Bachelors      m               other                1
# 3            38562  Bachelors      f               other                3
# 4            64486  Bachelors      m            sourcing                1
# ...            ...        ...    ...                 ...              ...
# 17410        57239  Bachelors      m               other                1
# 17411        73858  Bachelors      m            sourcing                2
# 17412        64573  Bachelors      f            referred                2
# 17413        49584  Bachelors      m               other                1
# 17416        64573  Bachelors      f            referred                1
#
#        age  previous_year_rating  length_of_service  KPIs_met_more_than_80  \
# ...

# %%
# Perform one-hot encoding
data_encoded = pd.get_dummies(data, columns=['education', 'gender', 'recruitment_channel'], drop_first=True)
# Drop the original categorical columns
data = data.drop(columns=['education', 'gender','recruitment_channel'])
# Display the resulting DataFrame
print(data_encoded)
# Out:
#        employee_id  no_of_trainings  age  previous_year_rating  \
# 0             8724                1   24                   3.0
# 1            74430                1   31                   3.0
# 2            72255                1   31                   1.0
# 3            38562                3   31                   2.0
# 4            64486                1   30                   4.0
# ...            ...              ...  ...                   ...
# 17410        57239                1   42                   3.0
# 17411        73858                2   28                   2.0
# 17412        64573                2   30                   5.0
# 17413        49584                1   33                   1.0
# 17416        64573                1   35                   5.0
#
#        length_of_service  KPIs_met_more_than_80  awards_won  \
# 0                      1                      1           0
# 1                      5                      0           0
# ...

# %%
#finally we have encoded the data which can be used to train ML model.
